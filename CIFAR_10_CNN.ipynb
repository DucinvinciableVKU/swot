# %% [markdown]
# <a href="https://colab.research.google.com/github/DucinvinciableVKU/swot/blob/master/CIFAR_10_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Split CIFAR-10 into training, validation, and testing sets

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import PIL

train_transform = transforms.Compose(
    [transforms.RandomHorizontalFlip(p=0.5),
     transforms.RandomAffine(degrees=(-5, 5), translate=(0.1, 0.1), scale=(0.9, 1.1), interpolation=PIL.Image.BILINEAR),
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

test_transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
train_set, val_set = torch.utils.data.random_split(dataset, [40000, 10000])

train_loader = torch.utils.data.DataLoader(train_set, batch_size=128, shuffle=True, num_workers=8)
val_loader = torch.utils.data.DataLoader(val_set, batch_size=128, shuffle=False, num_workers=8)

test_set = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=128, shuffle=False, num_workers=8)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# 100%|██████████| 170M/170M [00:03<00:00, 44.1MB/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()

# %% [markdown]
# ## Visualize image for each class

# %%
import matplotlib.pyplot as plt
import numpy as np

# visualize training image for each class
sample_images = [dataset.data[np.asarray(dataset.targets) == label][0] for label in range(10)]
# show images
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
i = 0
for row in axes:
  for axis in row:
    axis.set_xticks([])
    axis.set_yticks([])
    axis.set_xlabel(classes[i], fontsize=15)
    axis.imshow(sample_images[i])
    i += 1

# %% [markdown]
# ## Define CNN architecture

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.conv1 = nn.Conv2d(3, 128, 5, padding=2)
    self.conv2 = nn.Conv2d(128, 128, 5, padding=2)
    self.conv3 = nn.Conv2d(128, 256, 3, padding=1)
    self.conv4 = nn.Conv2d(256, 256, 3, padding=1)
    self.pool = nn.MaxPool2d(2, 2)
    self.bn_conv1 = nn.BatchNorm2d(128)
    self.bn_conv2 = nn.BatchNorm2d(128)
    self.bn_conv3 = nn.BatchNorm2d(256)
    self.bn_conv4 = nn.BatchNorm2d(256)
    self.bn_dense1 = nn.BatchNorm1d(1024)
    self.bn_dense2 = nn.BatchNorm1d(512)
    self.dropout_conv = nn.Dropout2d(p=0.25)
    self.dropout = nn.Dropout(p=0.5)
    self.fc1 = nn.Linear(256 * 8 * 8, 1024)
    self.fc2 = nn.Linear(1024, 512)
    self.fc3 = nn.Linear(512, 10)

  def conv_layers(self, x):
    out = F.relu(self.bn_conv1(self.conv1(x)))
    out = F.relu(self.bn_conv2(self.conv2(out)))
    out = self.pool(out)
    out = self.dropout_conv(out)
    out = F.relu(self.bn_conv3(self.conv3(out)))
    out = F.relu(self.bn_conv4(self.conv4(out)))
    out = self.pool(out)
    out = self.dropout_conv(out)
    return out

  def dense_layers(self, x):
    out = F.relu(self.bn_dense1(self.fc1(x)))
    out = self.dropout(out)
    out = F.relu(self.bn_dense2(self.fc2(out)))
    out = self.dropout(out)
    out = self.fc3(out)
    return out

  def forward(self, x):
    out = self.conv_layers(x)
    out = out.view(-1, 256 * 8 * 8)
    out = self.dense_layers(out)
    return out

net = Net()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('Device:', device)
net.to(device)

num_params = sum(p.numel() for p in net.parameters() if p.requires_grad)
print("Number of trainable parameters:", num_params)
# Out:
# Device: cuda:0
# Number of trainable parameters: 18617482

# %% [markdown]
# ## Training

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.01, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, min_lr=0)

loss_hist, acc_hist = [], []
loss_hist_val, acc_hist_val = [], []

for epoch in range(140):
  running_loss = 0.0
  correct = 0
  for data in train_loader:
    batch, labels = data
    batch, labels = batch.to(device), labels.to(device)

    optimizer.zero_grad()
    outputs = net(batch)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    # compute training statistics
    _, predicted = torch.max(outputs, 1)
    correct += (predicted == labels).sum().item()
    running_loss += loss.item()

  avg_loss = running_loss / len(train_set)
  avg_acc = correct / len(train_set)
  loss_hist.append(avg_loss)
  acc_hist.append(avg_acc)

  # validation statistics
  net.eval()
  with torch.no_grad():
    loss_val = 0.0
    correct_val = 0
    for data in val_loader:
      batch, labels = data
      batch, labels = batch.to(device), labels.to(device)
      outputs = net(batch)
      loss = criterion(outputs, labels)
      _, predicted = torch.max(outputs, 1)
      correct_val += (predicted == labels).sum().item()
      loss_val += loss.item()
    avg_loss_val = loss_val / len(val_set)
    avg_acc_val = correct_val / len(val_set)
    loss_hist_val.append(avg_loss_val)
    acc_hist_val.append(avg_acc_val)
  net.train()

  scheduler.step(avg_loss_val)
  print('[epoch %d] loss: %.5f accuracy: %.4f val loss: %.5f val accuracy: %.4f' % (epoch + 1, avg_loss, avg_acc, avg_loss_val, avg_acc_val))
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# [epoch 1] loss: 0.01414 accuracy: 0.3490 val loss: 0.01144 val accuracy: 0.4723
# [epoch 2] loss: 0.01158 accuracy: 0.4626 val loss: 0.01019 val accuracy: 0.5346
# [epoch 3] loss: 0.01027 accuracy: 0.5287 val loss: 0.00909 val accuracy: 0.5893
# [epoch 4] loss: 0.00901 accuracy: 0.5877 val loss: 0.00786 val accuracy: 0.6524
# [epoch 5] loss: 0.00817 accuracy: 0.6358 val loss: 0.00694 val accuracy: 0.6884
# [epoch 6] loss: 0.00758 accuracy: 0.6619 val loss: 0.00642 val accuracy: 0.7185
# [epoch 7] loss: 0.00707 accuracy: 0.6847 val loss: 0.00573 val accuracy: 0.7452
# [epoch 8] loss: 0.00668 accuracy: 0.7055 val loss: 0.00561 val accuracy: 0.7518
# [epoch 9] loss: 0.00637 accuracy: 0.7215 val loss: 0.00563 val accuracy: 0.7485
# [epoch 10] loss: 0.00607 accuracy: 0.7327 val loss: 0.00520 val accuracy: 0.7745
# [epoch 11] loss: 0.00582 accuracy: 0.7428 val loss: 0.00492 val accuracy: 0.7867
# [epoch 12] loss: 0.00562 accuracy: 0.7550 val loss: 0.00470 val accuracy: 0.7954
# [epoch 13] loss: 0.00544 accuracy: 0.7616 val loss: 0.00459 val accuracy: 0.7988
# [epoch 14] loss: 0.00527 accuracy: 0.7710 val loss: 0.00463 val accuracy: 0.8019
# [epoch 15] loss: 0.00506 accuracy: 0.7797 val loss: 0.00421 val accuracy: 0.8175
# [epoch 16] loss: 0.00486 accuracy: 0.7879 val loss: 0.00411 val accuracy: 0.8218
# [epoch 17] loss: 0.00480 accuracy: 0.7903 val loss: 0.00413 val accuracy: 0.8162
# [epoch 18] loss: 0.00469 accuracy: 0.7972 val loss: 0.00420 val accuracy: 0.8162
# [epoch 19] loss: 0.00460 accuracy: 0.8000 val loss: 0.00393 val accuracy: 0.8310
# [epoch 20] loss: 0.00448 accuracy: 0.8066 val loss: 0.00392 val accuracy: 0.8341
# [epoch 21] loss: 0.00434 accuracy: 0.8116 val loss: 0.00396 val accuracy: 0.8308
# [epoch 22] loss: 0.00425 accuracy: 0.8134 val loss: 0.00373 val accuracy: 0.8416
# [epoch 23] loss: 0.00417 accuracy: 0.8193 val loss: 0.00357 val accuracy: 0.8499
# [epoch 24] loss: 0.00405 accuracy: 0.8243 val loss: 0.00369 val accuracy: 0.8431
# [epoch 25] loss: 0.00399 accuracy: 0.8269 val loss: 0.00350 val accuracy: 0.8520
# [epoch 26] loss: 0.00389 accuracy: 0.8307 val loss: 0.00348 val accuracy: 0.8543
# [epoch 27] loss: 0.00388 accuracy: 0.8339 val loss: 0.00336 val accuracy: 0.8510
# [epoch 28] loss: 0.00378 accuracy: 0.8351 val loss: 0.00346 val accuracy: 0.8522
# [epoch 29] loss: 0.00370 accuracy: 0.8396 val loss: 0.00344 val accuracy: 0.8579
# [epoch 30] loss: 0.00366 accuracy: 0.8427 val loss: 0.00347 val accuracy: 0.8537
# [epoch 31] loss: 0.00361 accuracy: 0.8448 val loss: 0.00329 val accuracy: 0.8607
# [epoch 32] loss: 0.00352 accuracy: 0.8454 val loss: 0.00316 val accuracy: 0.8643
# [epoch 33] loss: 0.00346 accuracy: 0.8488 val loss: 0.00337 val accuracy: 0.8548
# [epoch 34] loss: 0.00338 accuracy: 0.8527 val loss: 0.00319 val accuracy: 0.8613
# [epoch 35] loss: 0.00330 accuracy: 0.8542 val loss: 0.00326 val accuracy: 0.8632
# [epoch 36] loss: 0.00330 accuracy: 0.8564 val loss: 0.00322 val accuracy: 0.8649
# [epoch 37] loss: 0.00328 accuracy: 0.8591 val loss: 0.00318 val accuracy: 0.8684
# [epoch 38] loss: 0.00317 accuracy: 0.8623 val loss: 0.00312 val accuracy: 0.8655
# [epoch 39] loss: 0.00316 accuracy: 0.8630 val loss: 0.00310 val accuracy: 0.8691
# [epoch 40] loss: 0.00305 accuracy: 0.8680 val loss: 0.00308 val accuracy: 0.8696
# [epoch 41] loss: 0.00305 accuracy: 0.8679 val loss: 0.00309 val accuracy: 0.8702
# [epoch 42] loss: 0.00298 accuracy: 0.8732 val loss: 0.00311 val accuracy: 0.8741
# [epoch 43] loss: 0.00294 accuracy: 0.8729 val loss: 0.00309 val accuracy: 0.8696
# [epoch 44] loss: 0.00295 accuracy: 0.8712 val loss: 0.00317 val accuracy: 0.8633
# [epoch 45] loss: 0.00296 accuracy: 0.8714 val loss: 0.00293 val accuracy: 0.8756
# [epoch 46] loss: 0.00281 accuracy: 0.8774 val loss: 0.00311 val accuracy: 0.8738
# [epoch 47] loss: 0.00287 accuracy: 0.8751 val loss: 0.00301 val accuracy: 0.8709
# [epoch 48] loss: 0.00281 accuracy: 0.8766 val loss: 0.00297 val accuracy: 0.8766
# [epoch 49] loss: 0.00277 accuracy: 0.8789 val loss: 0.00291 val accuracy: 0.8769
# [epoch 50] loss: 0.00272 accuracy: 0.8817 val loss: 0.00288 val accuracy: 0.8814
# [epoch 51] loss: 0.00269 accuracy: 0.8833 val loss: 0.00286 val accuracy: 0.8787
# [epoch 52] loss: 0.00263 accuracy: 0.8841 val loss: 0.00294 val accuracy: 0.8780
# [epoch 53] loss: 0.00265 accuracy: 0.8851 val loss: 0.00295 val accuracy: 0.8753
# [epoch 54] loss: 0.00259 accuracy: 0.8853 val loss: 0.00287 val accuracy: 0.8803
# [epoch 55] loss: 0.00252 accuracy: 0.8904 val loss: 0.00289 val accuracy: 0.8858
# [epoch 56] loss: 0.00250 accuracy: 0.8917 val loss: 0.00275 val accuracy: 0.8847
# [epoch 57] loss: 0.00251 accuracy: 0.8892 val loss: 0.00289 val accuracy: 0.8796
# [epoch 58] loss: 0.00244 accuracy: 0.8932 val loss: 0.00299 val accuracy: 0.8782
# [epoch 59] loss: 0.00250 accuracy: 0.8908 val loss: 0.00291 val accuracy: 0.8826
# [epoch 60] loss: 0.00246 accuracy: 0.8929 val loss: 0.00279 val accuracy: 0.8859
# [epoch 61] loss: 0.00242 accuracy: 0.8939 val loss: 0.00295 val accuracy: 0.8815
# [epoch 62] loss: 0.00236 accuracy: 0.8966 val loss: 0.00287 val accuracy: 0.8828
# [epoch 63] loss: 0.00232 accuracy: 0.8992 val loss: 0.00302 val accuracy: 0.8810
# [epoch 64] loss: 0.00231 accuracy: 0.9001 val loss: 0.00280 val accuracy: 0.8861
# [epoch 65] loss: 0.00229 accuracy: 0.8996 val loss: 0.00284 val accuracy: 0.8852
# [epoch 66] loss: 0.00228 accuracy: 0.9016 val loss: 0.00310 val accuracy: 0.8747
# [epoch 67] loss: 0.00228 accuracy: 0.8993 val loss: 0.00281 val accuracy: 0.8867
# [epoch 68] loss: 0.00196 accuracy: 0.9146 val loss: 0.00258 val accuracy: 0.8920
# [epoch 69] loss: 0.00177 accuracy: 0.9219 val loss: 0.00261 val accuracy: 0.8939
# [epoch 70] loss: 0.00168 accuracy: 0.9265 val loss: 0.00260 val accuracy: 0.8958
# [epoch 71] loss: 0.00167 accuracy: 0.9269 val loss: 0.00262 val accuracy: 0.8974
# [epoch 72] loss: 0.00168 accuracy: 0.9277 val loss: 0.00258 val accuracy: 0.8983
# [epoch 73] loss: 0.00165 accuracy: 0.9279 val loss: 0.00260 val accuracy: 0.8981
# [epoch 74] loss: 0.00160 accuracy: 0.9295 val loss: 0.00258 val accuracy: 0.8982
# [epoch 75] loss: 0.00154 accuracy: 0.9325 val loss: 0.00253 val accuracy: 0.9014
# [epoch 76] loss: 0.00155 accuracy: 0.9314 val loss: 0.00258 val accuracy: 0.8990
# [epoch 77] loss: 0.00155 accuracy: 0.9327 val loss: 0.00257 val accuracy: 0.8982
# [epoch 78] loss: 0.00156 accuracy: 0.9338 val loss: 0.00255 val accuracy: 0.8992
# [epoch 79] loss: 0.00148 accuracy: 0.9338 val loss: 0.00263 val accuracy: 0.8961
# [epoch 80] loss: 0.00146 accuracy: 0.9355 val loss: 0.00256 val accuracy: 0.9016
# [epoch 81] loss: 0.00144 accuracy: 0.9367 val loss: 0.00256 val accuracy: 0.9020
# [epoch 82] loss: 0.00142 accuracy: 0.9379 val loss: 0.00255 val accuracy: 0.9004
# [epoch 83] loss: 0.00142 accuracy: 0.9378 val loss: 0.00253 val accuracy: 0.8997
# [epoch 84] loss: 0.00143 accuracy: 0.9373 val loss: 0.00249 val accuracy: 0.9033
# [epoch 85] loss: 0.00141 accuracy: 0.9379 val loss: 0.00252 val accuracy: 0.9040
# [epoch 86] loss: 0.00140 accuracy: 0.9388 val loss: 0.00260 val accuracy: 0.9005
# [epoch 87] loss: 0.00139 accuracy: 0.9403 val loss: 0.00254 val accuracy: 0.9014
# [epoch 88] loss: 0.00142 accuracy: 0.9382 val loss: 0.00252 val accuracy: 0.9024
# [epoch 89] loss: 0.00136 accuracy: 0.9398 val loss: 0.00243 val accuracy: 0.9036
# [epoch 90] loss: 0.00137 accuracy: 0.9401 val loss: 0.00251 val accuracy: 0.9013
# [epoch 91] loss: 0.00134 accuracy: 0.9416 val loss: 0.00245 val accuracy: 0.9071
# [epoch 92] loss: 0.00133 accuracy: 0.9426 val loss: 0.00245 val accuracy: 0.9021
# [epoch 93] loss: 0.00134 accuracy: 0.9403 val loss: 0.00248 val accuracy: 0.9008
# [epoch 94] loss: 0.00131 accuracy: 0.9424 val loss: 0.00251 val accuracy: 0.9036
# [epoch 95] loss: 0.00132 accuracy: 0.9421 val loss: 0.00258 val accuracy: 0.9035
# [epoch 96] loss: 0.00135 accuracy: 0.9408 val loss: 0.00247 val accuracy: 0.9008
# [epoch 97] loss: 0.00130 accuracy: 0.9431 val loss: 0.00249 val accuracy: 0.9054
# [epoch 98] loss: 0.00128 accuracy: 0.9438 val loss: 0.00256 val accuracy: 0.9024
# [epoch 99] loss: 0.00127 accuracy: 0.9437 val loss: 0.00257 val accuracy: 0.9051
# [epoch 100] loss: 0.00129 accuracy: 0.9433 val loss: 0.00246 val accuracy: 0.9060
# [epoch 101] loss: 0.00127 accuracy: 0.9460 val loss: 0.00257 val accuracy: 0.9017
# [epoch 102] loss: 0.00123 accuracy: 0.9469 val loss: 0.00244 val accuracy: 0.9064
# [epoch 103] loss: 0.00124 accuracy: 0.9449 val loss: 0.00250 val accuracy: 0.9024
# [epoch 104] loss: 0.00125 accuracy: 0.9450 val loss: 0.00248 val accuracy: 0.9063
# [epoch 105] loss: 0.00122 accuracy: 0.9467 val loss: 0.00252 val accuracy: 0.9041
# [epoch 106] loss: 0.00124 accuracy: 0.9465 val loss: 0.00245 val accuracy: 0.9028
# [epoch 107] loss: 0.00123 accuracy: 0.9460 val loss: 0.00246 val accuracy: 0.9039
# [epoch 108] loss: 0.00122 accuracy: 0.9464 val loss: 0.00250 val accuracy: 0.9045
# [epoch 109] loss: 0.00122 accuracy: 0.9456 val loss: 0.00254 val accuracy: 0.9056
# [epoch 110] loss: 0.00121 accuracy: 0.9460 val loss: 0.00252 val accuracy: 0.9027
# [epoch 111] loss: 0.00120 accuracy: 0.9478 val loss: 0.00247 val accuracy: 0.9039
# [epoch 112] loss: 0.00127 accuracy: 0.9439 val loss: 0.00260 val accuracy: 0.9019
# [epoch 113] loss: 0.00125 accuracy: 0.9445 val loss: 0.00255 val accuracy: 0.9021
# [epoch 114] loss: 0.00124 accuracy: 0.9456 val loss: 0.00254 val accuracy: 0.9049
# [epoch 115] loss: 0.00122 accuracy: 0.9476 val loss: 0.00260 val accuracy: 0.9007
# [epoch 116] loss: 0.00123 accuracy: 0.9476 val loss: 0.00258 val accuracy: 0.9024
# [epoch 117] loss: 0.00121 accuracy: 0.9466 val loss: 0.00250 val accuracy: 0.9050
# [epoch 118] loss: 0.00122 accuracy: 0.9470 val loss: 0.00250 val accuracy: 0.9052
# [epoch 119] loss: 0.00121 accuracy: 0.9459 val loss: 0.00252 val accuracy: 0.9050
# [epoch 120] loss: 0.00120 accuracy: 0.9466 val loss: 0.00257 val accuracy: 0.9030
# [epoch 121] loss: 0.00119 accuracy: 0.9485 val loss: 0.00251 val accuracy: 0.9053
# [epoch 122] loss: 0.00123 accuracy: 0.9461 val loss: 0.00252 val accuracy: 0.9036
# [epoch 123] loss: 0.00122 accuracy: 0.9465 val loss: 0.00256 val accuracy: 0.9030
# [epoch 124] loss: 0.00122 accuracy: 0.9466 val loss: 0.00252 val accuracy: 0.9049
# [epoch 125] loss: 0.00122 accuracy: 0.9462 val loss: 0.00254 val accuracy: 0.9027
# [epoch 126] loss: 0.00122 accuracy: 0.9470 val loss: 0.00246 val accuracy: 0.9064
# [epoch 127] loss: 0.00120 accuracy: 0.9469 val loss: 0.00255 val accuracy: 0.9032
# [epoch 128] loss: 0.00122 accuracy: 0.9472 val loss: 0.00240 val accuracy: 0.9050
# [epoch 129] loss: 0.00122 accuracy: 0.9464 val loss: 0.00250 val accuracy: 0.9056
# [epoch 130] loss: 0.00124 accuracy: 0.9454 val loss: 0.00256 val accuracy: 0.9037
# [epoch 131] loss: 0.00122 accuracy: 0.9470 val loss: 0.00255 val accuracy: 0.9029
# [epoch 132] loss: 0.00122 accuracy: 0.9469 val loss: 0.00251 val accuracy: 0.9034
# [epoch 133] loss: 0.00124 accuracy: 0.9459 val loss: 0.00239 val accuracy: 0.9069
# [epoch 134] loss: 0.00118 accuracy: 0.9478 val loss: 0.00248 val accuracy: 0.9037
# [epoch 135] loss: 0.00119 accuracy: 0.9469 val loss: 0.00256 val accuracy: 0.9015
# [epoch 136] loss: 0.00121 accuracy: 0.9465 val loss: 0.00260 val accuracy: 0.9041
# [epoch 137] loss: 0.00122 accuracy: 0.9466 val loss: 0.00251 val accuracy: 0.9025
# [epoch 138] loss: 0.00122 accuracy: 0.9464 val loss: 0.00255 val accuracy: 0.9032
# [epoch 139] loss: 0.00118 accuracy: 0.9480 val loss: 0.00253 val accuracy: 0.9039
# [epoch 140] loss: 0.00119 accuracy: 0.9479 val loss: 0.00246 val accuracy: 0.9039

# %% [markdown]
# ## Plotting training statistics

# %%
import matplotlib.pyplot as plt

legend = ['Train', 'Validation']
plt.plot(loss_hist)
plt.plot(loss_hist_val)
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(legend, loc='upper left')
plt.show()

legend = ['Train', 'Validation']
plt.plot(acc_hist)
plt.plot(acc_hist_val)
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(legend, loc='upper left')
plt.show()

# %% [markdown]
# ## Save the trained model

# %%
from google.colab import files

torch.save(net.state_dict(), 'checkpoint.pth')
# download checkpoint file
files.download('checkpoint.pth')

# %%
net.load_state_dict(torch.load('checkpoint.pth'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Testing

# %%
pred_vec = []
correct = 0
net.eval()
with torch.no_grad():
    for data in test_loader:
        batch, labels = data
        batch, labels = batch.to(device), labels.to(device)
        outputs = net(batch)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        pred_vec.append(predicted)
    pred_vec = torch.cat(pred_vec)

print('Accuracy on the 10000 test images: %.2f %%' % (100 * correct / len(test_set)))
# Out:
# Accuracy on the 10000 test images: 90.24 %

# %% [markdown]
# ## Visualize wrongly classified image for each class

# %%
import numpy as np

# visualize wrongly classified image for each class
pred_vec = pred_vec.cpu().numpy()
ground_truths = np.asarray(test_set.targets)
incorrect_mask = pred_vec != ground_truths
incorrect_images = [test_set.data[(ground_truths == label) & incorrect_mask][0] for label in range(10)]
pred_results = [pred_vec[(ground_truths == label) & incorrect_mask][0] for label in range(10)]

# show images
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
i = 0
for row in axes:
  for axis in row:
    axis.set_xticks([])
    axis.set_yticks([])
    axis.set_xlabel("Predicted: %s" % classes[pred_results[i]], fontsize=14)
    axis.imshow(incorrect_images[i])
    i += 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3482/3491224838.py in <cell line: 0>()
#       2
#       3 # visualize wrongly classified image for each class
# ----> 4 pred_vec = pred_vec.cpu().numpy()
#       5 ground_truths = np.asarray(test_set.targets)
#       6 incorrect_mask = pred_vec != ground_truths
#
# AttributeError: 'numpy.ndarray' object has no attribute 'cpu'
